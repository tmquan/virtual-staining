# %%
data_dir = "data/ACT2_co-register/"

# %%
# %%bash
# tree -L 4 data/ACT2_co-register/Subject4_Slide4AIN1/
# Out:
# data/ACT2_co-register/Subject4_Slide4AIN1/
# ├── Session1
# │   ├── Acquisition1_NanoZoomer_20X_noparaffin_aqueouscoverslip_BF
# │   │   ├── 10_WJT-VS-noparaffin-Glycerol-coverslip-BF-20X-Slide4_AIN1-NZ - 2024-09-20 09p32p32_trim_cropped1_reg_full_section_fixed.tiff
# │   │   └── 15_WJT-VS-HE-BF-20X-Slide4_AIN1-NZ - 2024-10-04 11p38p55_trim_cropped1_full_section_fixed.tiff
# │   ├── Acquisition2_NanoZoomer_20X_noparaffin_nonaqueouscoverslip_BF
# │   │   ├── 11_WJT-VS-noparaffin-coverslip-BF-20X-Slide4_AIN1-NZ  - 2024-09-26 09p28p08_trim_cropped1_reg_full_section_fixed.tiff
# │   │   └── 15_WJT-VS-HE-BF-20X-Slide4_AIN1-NZ - 2024-10-04 11p38p55_trim_cropped1_full_section_fixed.tiff
# │   ├── Acquisition3_NanoZoomer_20X_noparaffin_uncoverslip_BF
# │   │   ├── 05_WJT-VS-noparaffin-uncoverslip-BF-20X-Slide4_AIN1-NZ - 2024-09-12 10p53p21_trim_cropped1_reg_full_section_fixed.tiff
# │   │   └── 15_WJT-VS-HE-BF-20X-Slide4_AIN1-NZ - 2024-10-04 11p38p55_trim_cropped1_full_section_fixed.tiff
# ...
